# %%
import pandas as pd

# %%
data = pd.read_csv("")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read
#
# AttributeError: module 'pandas' has no attribute 'read'
